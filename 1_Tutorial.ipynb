# %% [markdown]
# ### Data Reading JSON

# %%
df_json = spark.read.format('json')\
    .option('header',True)\
    .option('inferSchema',True)\
    .load('/Volumes/catalog/default/new_volume/drivers.json')

# %%
df_json.display()

# %%
# df_json = spark.read.format('json').option('inferSchema', True).option('header',True)\
#     .option('multiline', False)\
#     .load('catalog.default.drivers')

# %%
# # Note: The path 'catalog.default.drivers' in Cell 3 needs to be an absolute path
# # Either use: /Volumes/catalog/default/drivers/ (for files in a volume)
# # Or use: spark.table('catalog.default.drivers') (if it's a registered table)
# # df_json = spark.read.format('json').option('inferSchema', True).option('header',True)\
# #     .option('multiline', False)\
# #     .load('/Volumes/catalog/default/drivers/')

# df_json = spark.table('catalog.default.drivers')
    
# display(df_json)

# %% [markdown]
# ### Data Reading

# %%
df = spark.table('workspace.pysparktutorial.big_mart_sales')
display(df)

# %%
# spark.read.format('csv').option('inferSchema','true').option('header', 'true').load('workspace.pysparktutorial.big_mart_sales').display()

# %%
# display(spark.read.table('catalog.default.big_mart_sales'))

# %%
display(spark.table('workspace.pysparktutorial.big_mart_sales'))

# %%
df.show()

# %%
df.display()

# %%
display(df)
